# %% [markdown]
# <a href="https://colab.research.google.com/github/anitapoudel-321/my_project/blob/main/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# operators , oprand and opration
#
# * operators: symbol that perform a task.
#
# * oprand: value in which opration is performed.
#
# * process of calculation

# %% [markdown]
# 1) arthmeric operator :a = 10
# b = 3
#
# * print(a + b)  # add
# * print(a - b)  # subtract
# * print(a * b)  # multiply
# * print(a / b)  # divide
# * print(a % b)  # remainder
# * print(a ** b) # power
# * print(a // b) # floor division

# %%
2**3
# Out:
# 8

# %%
a=10
b=3
print(a//b)
# Out:
# 3

# %% [markdown]
# 2) relational operation: compare 2 values

# %%
a = 10
b = 5

print(a > b)
print(a < b)
print(a == b)
print(a != b)
# Out:
# True
# False
# False
# True

# %% [markdown]
# 3) logical operation: used to combine condition and return true or false

# %%
a=2
c=4
print(a>b and a>c)
print (a>b or a>c)
print(not a>b)
# Out:
# False
# False
# True

# %% [markdown]
# 4) assignment operator - assign values to variable and also update them

# %%
a=3
a+=3
a
# Out:
# 6

# %% [markdown]
# 5) bitwise operator: it works on binary form (0 and 1)
# * bitwise not,or,xor,and...

# %%
a=11
b=22
print(a&b)
print(a|b)
# Out:
# 2
# 31

# %% [markdown]
# attributes - attributes are variable inside the class ,purpose is to store data
#
# method - function , purpose is to perform action

# %% [markdown]
# variable:
#
#      variable is a container that holds the value (number, text) and canbe used later in program.
# - must start with alphabet or underscore(_)
# - cannot use kwyboard
# - case sensative
# - can contain _ ,alphabet and number

# %%
a=2.4
type(a)
# Out:
# float

# %% [markdown]
# data type is a classification of data type that defines what type of value a variable holds.
# 1. numeric data type - int ,float,complex
# 2. boolean data type - bool
# 3. sequence data type - list,tuple ,range
# 4. mapping data type -dict
# 5. text data type-text
# 6. binary data type- bytes,bytearray,memoryview
# 7. set data type-set

# %% [markdown]
# 1.numerc data type :  numerical data type stores a number as int,float,complex

# %%
a=complex(5,3)
print(a)
print("the type of a",type(a))
# Out:
# (5+3j)
# the type of a <class 'complex'>

# %% [markdown]
# 2. boolean data type only represent only 2 values either true or false

# %%
a="true"
b="false"
type(a)
# Out:
# str

# %% [markdown]
# 3.  sequence data type
#
#         list are the collection of diff data types .we can change the value later if we want..but in tuple we cannot change the value later .
#
#
#
#
# ---

# %%
a1=[2,3]
print("orginal valur:",a1)
a1[0] = 10
print("updated value:",a1)
# Out:
# orginal valur: [2, 3]
# updated value: [10, 3]

# %% [markdown]
# range syntax=range(start,stop,step)

# %%
total=0
for i in range(2,21,2):
  total+=i
print( "sum is:",total)
# Out:
# sum is: 110

# %% [markdown]
# 4) mapping data type is a data type that stores data in a key - value pairs

# %%
info = {
    "name": "Anita",
    "age": 18,
    "roll no": 68,
    "class": "10"
}

print(info["age"])
# Out:
# 18

# %% [markdown]
# 5.  text data type store the character in sequence.

# %%
sentence="i am a girl"
print(sentence)
# Out:
# i am a girl

# %% [markdown]
# 6.binary data stores the data in binary form. it is used for handling raw data like image,files in python it is divided into 3 types:
#
# 1.bytes-imutable(value cannot be change), syntax-bytes()
#
# 2.bytearray-mutable(can be change), syntax-bytearry()
#
# 3.memoryview

# %%
a=bytes([65,66,67])
print(a)
# Out:
# b'ABC'

# %%
a=bytearray([65,66,67])
a[0]=67
print(a)
# Out:
# bytearray(b'CBC')

# %% [markdown]
# 7.set:
#       set is a collection of items that is unordered,unindexed and donot allow duplicate value

# %%
a={1,2,3}
a.remove(3)
print(a)
# Out:
# {1, 2}

# %% [markdown]
# type of conversion - change the data type from one data type to another data type
# 1) implict data type- automatically convert
# 2) explict data type- mallually convert

# %%
a=2.3 #explict data type
int(a)
# Out:
# 2

# %%
a=2.5 #implict data type
b=3.5
print(a+b)
# Out:
# 6.0
