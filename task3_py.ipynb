# %% [markdown]
# <a href="https://colab.research.google.com/github/anitapoudel-321/my_project/blob/main/task3_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Integer & Float Mix**
# * Create an integer a and a float b.
# * Perform addition, subtraction, multiplication, and division on them.
# * Print the results and observe the type of each result with type().

# %%
a=10
b=23.44
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(type(a+b))
print(type(a-b))
print(type(a*b))
print(type(a/b))
# Out:
# 33.44
# -13.440000000000001
# 234.4
# 0.4266211604095563
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# 2. **Large Integers & Type**
# * Assign a very large integer to a variable (e.g., in the billions).
# * Print it and confirm its type is still int in Python or not.

# %%
i=400005000000
print(i)
print(type(i))
# Out:
# 400005000000
# <class 'int'>

# %% [markdown]
# 3. **Complex Number Basics**
#
# * Create a complex number z = 3 + 4j.
# * Print its real part, imaginary part, and confirm its type is complex.
# * Perform a basic arithmetic operation with another complex number (e.g., (3 + 4j) + (1 + 2j)).

# %%
z=3+4j
print("real part:",z.real)
print("img part:",z.imag)
print(type(z))
print("sum=",(3+4j)+(1+2j))
# Out:
# real part: 3.0
# img part: 4.0
# <class 'complex'>
# sum= (4+6j)

# %% [markdown]
# 4. **Boolean from Comparisons**
# * Create two variables, m = 10 and n = 15.
# * Define status = (m > n) and print status.
# Confirm type(status) is bool.
# Assign status = (m != n) and
#  * print again.
# String Creation & Indexing

# %%
m=10
n=15
status=(m>n)
print(status)
print(type(status))
status=(m!=n)
print(status)
print(type(status))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>

# %% [markdown]
# 5.**String Creation & Indexing**
#  * Create a string text = "HelloWorld".
# * Print the first and last characters using positive and negative indexing.
# * Comment on the total length of the string.

# %%
text="Helloword".upper()
print(text)
print(text[0])
print(text[-1])
print(len(text))
# Out:
# HELLOWORD
# H
# D
# 9

# %% [markdown]
# 6. **String Slicing**
# * With lang = "PythonProgramming", print the substring from index 2 to 8.
# * Print the substring from the start up to index 5.
# * Print the entire string in reverse using slicing.

# %%
lang="pythomprogramming"
print(lang[2:10])
print(lang[0:5])
print(lang[-1::-1])
# Out:
# thomprog
# pytho
# gnimmargorpmohtyp

# %% [markdown]
# 7. **String Methods **
# * Let phrase = " Hello, Python World! ".
# * Demonstrate strip(), upper(), and replace() on this string.
# * Print the results and comment on immutability of strings in Python.

# %%
phrase="hello,python World"
print(phrase.strip()) #remove space
print(phrase.upper()) # make capital characters
print(phrase.replace("python","java")) # replacethe string
print(phrase)
# Out:
# hello,python World
# HELLO,PYTHON WORLD
# hello,java World
# hello,python World

# %% [markdown]
# 8. **String Formatting**
# * Create two variables: name = "Rajesh" and score = 95.
# * Print: "Alice scored 95 points." using two methods (concatenation and an f-string or str.format()).

# %%
name="rajesh"
score=95
print(name+" scored "+str(score)+" points") #concatenation
print("{} scored {} points".format(name,score)) # an f-string
# Out:
# rajesh scored 95 points
# rajesh scored 95 points

# %% [markdown]
# **9. Boolean Operations in Expressions**
# * Write a small expression using and, or, and not with boolean values.
# * Example: result = not(True and False) or (5 > 3).
# * Print result and explain how Python evaluated the expression.

# %%
resutt=not(True and False) or (5>3) # AND: true if both of the condition are true otherwise false
                                    #OR: return true if any of the contition is right,return false if both condition are false
print(resutt)
# Out:
# True

# %% [markdown]
# 10. **List Creation & Access**
# * Create a list of 5 different integers.
# * Print the first item, middle item, and last item using indexing.

# %%
list=[2,3,4,5,6]
print(list[0])
print(list[2])
print(list[-1])
# Out:
# 2
# 4
# 6

# %% [markdown]
# 11. **List Insertion & Deletion**
# * Start with a list nums = [10, 20, 30, 40].
# * Insert 25 at index 2.
# * Remove the last element.
# * Print the updated list.

# %%
nums=[10,20,30,40]
print(nums.insert(2,25))
print(nums)
print(nums.pop())
print("updated list:",nums)
# Out:
# None
# [10, 20, 25, 30, 40]
# 40
# updated list: [10, 20, 25, 30]

# %% [markdown]
# 12. **List Slicing**
# * Given letters = ["a", "b", "c", "d", "e"], print the slice that contains only
# * ["b", "c", "d"].
# * Print the slice that omits the first and the last element.

# %%
letters=["a","b","c","d","e"]
print(letters[1:4])
print(letters[1:-1])
# Out:
# ['b', 'c', 'd']
# ['b', 'c', 'd']

# %% [markdown]
# 13. **Sorting & Reversing**
# * Create a list of random integers.
# * Sort the list in ascending order and print it.
# * Reverse the sorted list and print again.

# %%
i=(7,3,8,5)
print(sorted(i)) # in ascending order
print(sorted(i,reverse=True)) # in descending order rev the ascending order
# Out:
# [3, 5, 7, 8]
# [8, 7, 5, 3]

# %% [markdown]
# 14. **Combining Lists**
# * Let list1 = [1, 2, 3] and list2 = [4, 5, 6].
# * Combine them into a single list and print.
# * Demonstrate two ways: using + and using .extend().

# %%
list1=[1,2,3]
list2=[4,5,6]
print(list1+list2)
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 15. **Aggregating List Values**
# * Create a list of floats, e.g., [2.5, 3.6, 1.2, 5.0].
# * Print the sum, minimum, and maximum of that list using built-in functions.

# %%
f=[2.5,3.6,1.2,5.0]
print(sum(f))
print(min(f))
print(max(f))
# Out:
# 12.3
# 1.2
# 5.0

# %% [markdown]
# 16. **Tuple Creation**
# * Create a tuple t = (10, 20, "Hello", True).
# * Print the tuple and confirm its type with type(t).

# %%
t=(10,20,"Hello",True)
print(t)
type(t)
# Out:
# (10, 20, 'Hello', True)
# tuple

# %% [markdown]
# 17. **Tuple Indexing & Slicing**
# * Print the first two elements of t using slicing.
# * Print the last element of t using negative indexing.

# %%
t=(2,6,7)
print(t[0:2])
print(t[-1])
# Out:
# (2, 6)
# 7

# %% [markdown]
# 18. **Tuple Unpacking**
# * Suppose t2 = ("Tom", 25, "Engineer").
# * Unpack it into three separate variables: name, age, profession.
# * Print these variables individually.

# %%
t2=("Tom",25,"Engineer")
name,age,profession=t2
print(name)
print(age)
print(profession)
# Out:
# Tom
# 25
# Engineer

# %% [markdown]
# 19. **Attempt Tuple Mutation**
# * Try to change an element of t (t[0] = 999) and observe the error.
# * In comments, explain why the error occurs.

# %%
t=(2,4,5)
t[0]=999 # tuple is immutable we cannot chane the items. it has fixed items
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7183/1520012504.py in <cell line: 0>()
#       1 t=(2,4,5)
# ----> 2 t[0]=999
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 20. **Set Creation & Membership**
# * Create a set my_set = {1, 3, 5, 7}.
# * Check if 5 is in my_set.
# * Check if 2 is not in my_set.

# %%
my_set={1,3,5,7}
print(5 in my_set)
print(2 not in my_set)
# Out:
# True
# True

# %% [markdown]
# 21. **Add & Remove Elements**
# * Add 9 to my_set.
# * Remove 3 from my_set.
# * Print the updated set.

# %%
print(my_set.add(9))
print(my_set.remove(3))
print(my_set)
# Out:
# None
# None
# {1, 5, 7, 9}

# %% [markdown]
# 22.**Set Operations**
# * Create two sets: setA = {1, 2, 3} and setB = {3, 4, 5}.
# * Print the union, intersection, and difference (setA - setB).

# %%
setA={1,2,3}
setB={3,4,5}
print(setA.union(setB))
print(setA.intersection(setB))
print(setA.difference(setB))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [markdown]
# 22.**Check Unique Values**
# * Define a list vals = [1, 2, 2, 3, 3, 3, 4].
# * Convert it to a set.
# * Print both the list and the set to show how duplicates are removed.

# %%
valuel = [1, 2, 2, 3, 3, 3, 4]
values = set(valuel)
print("Original list:", valuel)
print("Set :", values)
# Out:
# Original list: [1, 2, 2, 3, 3, 3, 4]
# Set : {1, 2, 3, 4}

# %% [markdown]
# 23.**Frozenset Creation**
# * Create a frozenset from a list [2, 4, 4, 6].
# * Print it and observe whether duplicates are preserved.

# %%
l=[2,4,4,6]
f=frozenset(l) #remove duplacate value
print(f)
# Out:
# frozenset({2, 4, 6})

# %% [markdown]
# 24. **Operator Precedence**
# * Define a = 4, b = 2, c = 5.
# * Print the result of a + b * c vs. (a + b) * c.
# * Explain in comments how the result differs.

# %%
a=4
b=2
c=5
print(a+b*c)
print((a+b)*c)
# Out:
# 14
# 30

# %% [markdown]
# 25.**Modulo & Floor Division**
# * Let x = 17 and y = 4.
# Print x % y and x // y.
# * Explain the difference between these two operators in comments.

# %%
x=17
y=4
print(x%y) #remainder
print(x//y) #floor div , remoe decimal part after dividing
# Out:
# 1
# 4

# %% [markdown]
# 26. **Power Operator**
# * Print the result of 2 ** 3.
# * Write a line to calculate 3 ** 4.
# * Print the addition of both.

# %%
print(2**3)
print(3**4)
print(2**3+3**4)
# Out:
# 8
# 81
# 89

# %% [markdown]
# 26. **String Comparison**
# * Compare "apple" and
# "banana" with <, >, and ==.
# Print the results.

# %%
a="apple"
b="banana"
print(a<b)
print(a>b)
print(a==b)
# Out:
# True
# False
# False

# %% [markdown]
# 27. **Mixed Type Comparison**
# * Compare 5 and 5.0 with ==.
# * Compare 5 and 5.0 with is.
# * Discuss the results in comment.

# %%
i=5
f=5.0
print(i==f) #5=5.0 value is same
print(i is f) # is compares memory lacation int anf flloat are diff so it is false
# Out:
# True
# False

# %% [markdown]
# 29. **Chain Comparisons**
# * Evaluate the expression 2 < 3 < 5.
# * Print the result and explain how Python handles chained comparisons.

# %%
print(2<3<5) #2 < 3 → True 3 < 5 → True Both are True → final result is True
# Out:
# True

# %% [markdown]
# 30.Logical and
# Define
# * p = True and q = False.
# * Print p and q.
# * Demonstrate a real-world example: (age > 18) and (has_ID == True).

# %%
p=True
q=False
print(p)
print(q)
age=23
has_id=True
print((age>18) and (has_id==True))
# Out:
# True
# False
# True

# %% [markdown]
# 31.**Logical or**
# * Using the same p and q, print p or q.

# %%
p=True
q=False
print(p or q)
# Out:
# True

# %% [markdown]
# 32.**Logical not**
# * Let r = (10 > 5).
# Print r, then print not r.

# %%
r=(10>5)
print(r)
print(not r)
# Out:
# True
# False

# %% [markdown]
# 33.**Using len()**
# * Create a list with 7 elements.
# * Use len() to get the total count.
# * Print the result.

# %%
list=[1,3,2,4,5,6,4]
print("total count:",len(list))
# Out:
# total count: 7

# %% [markdown]
# 34.**Using type()**
# * For each of the following: 10, 10.5, "ten", True, 3+2j, print type(...).
# * Summarize in comments the data types you observed.

# %%
i=10,10.5,"ten",True,3+2j
type(i)
# Out:
# tuple

# %% [markdown]
# 35. **Using abs()**
# * Print abs(10), abs(-10), and abs(-3.5).
# * Explain what abs() does in comments.

# %%
#abs():absolute value
print(abs(10))
print(abs(-10))
print(abs(-3.5))
# Out:
# 10
# 10
# 3.5

# %% [markdown]
# 36.**Using round()**
# * Demonstrate round(3.14159, 2).
# * Show how round(2.5) behaves in Python.

# %%
print(round(3.14159,2)) #rounds the number to 2 decimal places
print(round(2.5))
# Out:
# 3.14
# 2

# %% [markdown]
# 37.**Using sum(), max(), min()**
# * Create a list of numeric values.
# * Print sum(), max(), and min() of that list.

# %%
l=[1,2,3,4,5]
print(sum(l))
print(max(l))
print(min(l))
# Out:
# 15
# 5
# 1

# %% [markdown]
# 38.**Using sorted()**
# * Create a list or tuple vals = (3, 1, 4, 2).
# * Use sorted(vals) and print the result.
# * Show that vals itself is unchanged.

# %%
vals=(3,1,4,2)
print(sorted(vals))
print(vals)
# Out:
# [1, 2, 3, 4]
# (3, 1, 4, 2)

# %% [markdown]
# 40.**Using any() / all()**
# * Create a list of booleans, for example [True, False, True].
# * Print any() on the list, then all() on the list.
# * Show the difference in how they evaluate.

# %%
b=[True,False,True]
print(any(b)) # in any if one of the item is true then return true
print(all(b)) # in all there should be all item true oherwise false
# Out:
# True
# False

# %% [markdown]
# 41. **Storing Booleans from Comparisons**
# * Compare two values in separate expressions, e.g., a = (10 > 3), b = (5 == 5).
# * Combine these booleans with and or or.
# Print the final result.

# %%
a=(10>3)
b=(5==5)
print(a and b)
print(a or b)
# Out:
# True
# True

# %% [markdown]
# 42**Multiline String & Counting**
# * Create a multiline string describing your favorite hobby.
# * Use the string method .count(substring) to count how many times the letter "a" appears (case-insensitive).
# * Print the count and explain any steps taken to handle case sensitivity.

# %%
fav_hobby= '''i like to sleep whole day and nigtht ,
 i can sleep anywhere any'''
c = (fav_hobby.lower().count('a')) # .lower() converts all letters to lowercase
print(c)
# Out:
# 5

# %% [markdown]
# 43. **Advanced String Slicing**
# * Take the string "ABCDEFGHIJ" and slice every second character, resulting in "ACEGI".
# * Print the sliced string.
# * Also slice in reverse step.

# %%
st="ABCDEFGHIJ"
print(st[0:9:2])
print(st[9:0:-2])
# Out:
# ACEGI
# JHFDB

# %% [markdown]
# 44.**Casefold vs. Lower**
# * Create two strings, "Case" and "case".
# * *Compare them with the regular == operator directly.
# * Compare them again after applying .casefold().
# * Print results and comment on how .casefold() differs from .lower() in edge cases.

# %%
st1="case"
st2="case"
print(st1==st2)
print(st1.casefold()==st2.casefold()) #casefold() is a string method used to convert a string into lowercase in a stronger way than lower()
# Out:
# True
# True

# %% [markdown]
# 45**Formatted Printing**
# * Define name = "Ramesh", product = "Notebook", quantity = 2, and price = 12.50.
# * Use an f-string (or str.format()) to print:
# "Ramesh purchased 2 Notebook for a total of $25.0."

# %%
name="Ramesh"
product="Notebook"
quantity=2
price=12.50
print(f"{name} purchased {quantity} {product} for a total of ${quantity*price}.")
# Out:
# Ramesh purchased 2 Notebook for a total of $25.0.

# %% [markdown]
# 46.**Type Conversion Chain**
# * Ask a user for a string that represents a number, e.g., "0".
# * Convert it to a float, then to a bool, and print the intermediate and final results.

# %%
s = "0"
f = float(s)
print("Float:", f)
b = bool(f)
print("Bool:",b)
# Out:
# Float: 0.0
# Bool: False

# %% [markdown]
# 47.**String List Sorting**
# * Given fruits = ["apple", "banana", "cherry"], sort them in descending alphabetical order.
# * Print the sorted list, then use the .reverse() method to flip it. Compare the two results.

# %%
fruits=["apple","banana","cherry"]
print(sorted(fruits,reverse=True))
print(fruits.reverse())
print(fruits)
# Out:
# ['cherry', 'banana', 'apple']
# None
# ['cherry', 'banana', 'apple']

# %% [markdown]
# 48.**Insert Using Slicing**
# * Start with a list [2, 5, 7, 1, 9].
# * Insert the value 4 right after the 2 using slicing (not insert() or append()).
# * Print the modified list.

# %%
list=[2,5,7,1,9]
list[1]= 4
print(list)
# Out:
# [2, 4, 7, 1, 9]

# %% [markdown]
# 50. **Indexing Within a Mixed List**
# * Create a list info = ["John", 28, True, 4500.75].
# * Print only "John" and 4500.75 using their indices.

# %%
list=["John",28,True,4500.75]
print(list[0])
print(list[3])
# Out:
# John
# 4500.75

# %% [markdown]
# 51. **Tuple Concatenation & Replication**
# * Create two tuples (1, 2) and (3, 4).
# * Concatenate them into (1, 2, 3, 4).
# * Replicate (1, 2) 3 times to get (1, 2, 1, 2, 1, 2).

# %%
t1=(1,2)
t2=(3,4)
print(t1+t2)
print(t1*3)

# %% [markdown]
# 52. **Single-Element Tuple**
# * Demonstrate that (42,) is a tuple whereas (42) is just an integer.

# %%
a = (42,) #tuple
b = (42) #int
print(type(a))
print(type(b))
# Out:
# <class 'tuple'>
# <class 'int'>

# %% [markdown]
# 53. **Intersection & Union**
# * Let setA = {1, 2, 3, 4} and setB = {1,2,3}.

# %%
setA={1,2,3,4}
setB={1,2,3}
print(setA.intersection(setB))
print(setA.union(setB))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}
