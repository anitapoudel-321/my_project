# %% [markdown]
# <a href="https://colab.research.google.com/github/anitapoudel-321/my_project/blob/main/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) **basic arthmetic and type idemtification**

# %%
i=32
f=21.23
c=complex(3,5)

# %% [markdown]
# * create three variables: one integer,one float ,and one complex number
# * print each variable and use the type() function to confirm their data types

# %%
print("integer value:",i)
type(i)
# Out:
# integer value: 32
# int

# %%
print("float value:",f)
type(f)
# Out:
# float value: 21.23
# float

# %%
print("comple no:",c)
print("Type:",type(c))
# Out:
# comple no: (3+5j)
# Type: <class 'complex'>

# %% [markdown]
# 2) **arthmetic with mixed types**

# %% [markdown]
# * create one int variable(a) and one float varianle(b)
# * print sum,difference,product,and quotient of and b
# * print the type() of each result (notice how types may change)

# %%
a=21
b=12.34

# %%
sum=(a+b)
print(sum)
type(sum)

# %%
diff=(a-b)
print(diff)
type(diff)

# %%
product= a * b
print("product:",product)
print(type(product))
# Out:
# product: 259.14
# <class 'float'>

# %%
quotient=(a/b)
print("quotient:",quotient)
print(type(quotient))
# Out:
# quotient: 1.7017828200972447
# <class 'float'>

# %% [markdown]
# **3) comparision operation**

# %% [markdown]
# * Let x= 10 and y= 7.
# * print the result of x>y,x<y,and X!=y.
# * after observing the output , explain why each result is true or false in comments

# %%
x=10
y=7
print("x>y:",x>y) #x is greater then y so codition is true
print("x<y:",x<y) # condition is false
print("x!y:",x!=y) #condition is true

# %% [markdown]
# **Boolean variables**

# %% [markdown]
# * define a variable status = true.
# * print the value of status and conform it is a boolean using type(status)
# * reassing status to false and conforms its type again

# %%
status=True
print(status)
type(status)

# %%
status=False
print(status)
type(status)

# %% [markdown]
# **String Creation and Length**

# %% [markdown]
# * Create a string variable, for example text = "Hello World".
# * Use len(text) to print its length.
# * Use type(text) to verify it is a string.

# %%
text="hello word"
print("lenfth of text:",len(text))
type(text)
# Out:
# lenfth of text: 10
# str

# %% [markdown]
# **String Indexing**

# %% [markdown]
# * With the string s = "Python", print each character. Then print just the first and last characters using negative indexing.

# %%
s="python"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
# Out:
# p
# y
# t
# h
# o
# n

# %%
print("first character:",s[-6])
print("last character:",s[-1])

# %% [markdown]
# 7) **String Slicing**

# %% [markdown]
# * Let lang = "Programming".
# Print the substring from index 0 to index 4.
# * Print the substring from index 3 to the end.
# * Print the substring that omits the first 2 and last 2 characters.

# %%
lang="programming"
print("indx 0 to 4:",(lang[0:4]))
print("indx 3 to end:",(lang[3:]))
print(lang[2:-2])

# %% [markdown]
# **Exploring len() on Slices**

# %% [markdown]
# * Continue using lang = "Programming".
# * Slice lang to get "Program" and store it in a variable part1.
# * Print len(part1) and comment how it differs from len(lang).

# %%
lang="programming"
part1=lang[0:7]
print(part1)
print(len(part1))
print(len(lang))

# %% [markdown]
# **String Methods – Case Conversion**

# %% [markdown]
# * Let phrase = "Hello, Python!".
# * Print phrase.upper() and phrase.lower().
# * Print the original phrase to show it remains unchanged (strings are immutable).

# %%
pharase="Hello, python"
print(pharase.upper())
print(pharase.lower())
pharase

# %% [markdown]
# 9) **Combining Strings**

# %% [markdown]
# * Combining Strings
# Create two strings, str1 = "Data" and str2 = "Science".
# * Combine them into a single string with a space in between and print it.
# * Print the length of the combined string.

# %%
str1="Data"
str2="science"
print(str1+" "+str2)
print(len(str1+" "+str2))
# Out:
# Data science
# 12

# %% [markdown]
# 10) **In-Place vs. Reassignment with String Methods**

# %% [markdown]
# * Let word = "example".
# * Call word.upper() but do not store it, then print word.
# * Now set word = word.upper(), then print word.
# * Comment on why the second print is different from the first.

# %%
word="example"
print(word.upper())
print(word)
word=word.upper() # in word value updated
print(word)

# %% [markdown]
# **Arithmetic Operator Precedence**

# %% [markdown]
# * Define a = 5, b = 3, c = 2.
# * Print the result of the expression a + b * c.
# * Print the result of (a + b) * c.
# * In comments, explain how operator precedence affects the outcome.

# %%
a=5
b=3
c=2
result1=a+b*c
print("a+b*c=",result1) # (* has more precedence affects than addition)
result2=(a+b)*c
print("(a+b)*c=",result2) # (first calculation happen inside small bracket() while calculation)

# %% [markdown]
# **String Index Out of Range**

# %% [markdown]
# * Let text = "Hello".
# * Attempt to access an index that doesn’t exist, like text[10]
# * Observe the error message (IndexError) and explain why it happens in comments.

# %%
text="Hello"
text[10] # index error bcz here index up to only(0-4 valid),only 5 character so there is error.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3155/3071013370.py in <cell line: 0>()
#       1 text="Hello"
# ----> 2 text[10] # index error bcz here index up to only(0-4 valid),only 5 character so there is error.
#
# IndexError: string index out of range

# %% [markdown]
# **Equality vs. Identity Check (Conceptual Explanation)**

# %% [markdown]
# * Create two variables with the same string value, s1 = "test" and s2 = "test".
# * Use the == operator to compare them, then use the is operator.
# * Explain in comments what each comparison checks.

# %%
s1="test"
s2="test"
s1==s2 #here the character of the string is same of s1 ans s2 so its true while comarision
# Out:
# True

# %% [markdown]
# **Creating and Checking a Complex Number**

# %% [markdown]
# * Define z = 3 + 4j.
# * Print the real part (z.real) and the imaginary part (z.imag).
# * Confirm that its type is complex using type(z).

# %%
z=3+4j
print("real part:",z.real)
print("imaginary part:",z.imag)
print("type:",type(z))
# Out:
# real part: 3.0
# imaginary part: 4.0
# type: <class 'complex'>

# %% [markdown]
# **Comparisons with Floats**

# %% [markdown]
# * Let f1 = 0.1 + 0.2 and f2 = 0.3.
# * Print f1 == f2.
# * Print the actual values of f1 and f2 to explain any difference in the comparison outcome (floating-point precision).

# %%
f1=(0.1+0.2)
f2=(0.3)
print(f1==f2)
print("f1:",f1)
print("f2:",f2)
# Out:
# False
# f1: 0.30000000000000004
# f2: 0.3
